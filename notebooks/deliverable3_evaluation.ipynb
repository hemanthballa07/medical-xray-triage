# %% [markdown]
# # Deliverable 3 - Extended Evaluation and Refinements
#
# This notebook demonstrates the enhanced evaluation pipeline for Deliverable 3.
#
# ## Changes Since Deliverable 2
#
# ### Key Improvements:
# - Bootstrap Confidence Intervals
# - Probability Calibration
# - Cross-Dataset Evaluation
# - Ablation Studies
# - Hyperparameter Sweeps
# - Audit Module
# - Enhanced UI

# %%
import sys
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
sys.path.append("../src")

results_dir = Path("../results")
eval_results_path = results_dir / "evaluation_results.json"

if eval_results_path.exists():
    with open(eval_results_path) as f:
        eval_results = json.load(f)
    print("✓ Loaded evaluation results")
    default_metrics = eval_results["thresholds"]["default"]["metrics"]
    print(f"AUROC: {default_metrics["auroc"]:.4f}")
    print(f"F1: {default_metrics["f1"]:.4f}")
else:
    print("⚠ Run: python src/eval_enhanced.py")
